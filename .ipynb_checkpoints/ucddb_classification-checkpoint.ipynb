# %% [markdown]
# # UCD sleep dataset: Evaluation of different classification strategies on a subset of the data

# %% [markdown]
# ## Original dataset and previous work

# %% [markdown]
# In Langkvist (2012), "Sleep Stage Classifiction Using Unsupervised Feature Learning", the authors wanted to classify different sleep stages using physiological information only. The raw data is freely available [online](http://physionet.org/pn3/ucddb/):
# * 25 participants
# * ~7 hours of recording per participant
# * Physiological signals
#  * EEG (C3, C4)
#  * EMG (face)
#  * EOG (2 channels)
# * 128 Hz (EEG), 64 Hz (EOG, EMG)
# * 5 sleep stages
#
# The authors tried three different architectures:
# 1. Feature extraction, Feature selection, PCA, GMM and HMM
# 2. Feature extraction, DBN and HMM
# 3. DBN and HMM
#
# Findings suggest that while all three methods yielded comparable results (64-72% on average in the 5-class classification task), the second architecture was slightly better.

# %% [markdown]
# ## Task and proposed approach

# %% [markdown]
# This notebook will explore different classification strategies on a subset of the dataset used in Langkvist (2012) (data and MATLAB code available [here](http://aass.oru.se/~mlt/)). Specifically, this subset is composed of:
# * 2 classes: drowsy (0) and awake (1)
# * 42,570 observations (computed on non-overlapping 1-second windows)
# * 7 types of features
#  * EEG frequency band powers: EEG_delta, EEG_theta, EEG_alpha, EEG_beta, EEG_gamma
#  * Standard deviation of an EOG channel: EOG_std
#  * EEG fractal dimension exponent: EEG_fractal_exponent
#
# Drowsy and awake labels are obtained from the original dataset (first stage of sleep and awake conditions), from which five subjects are extracted.
#
# Unlike Langkvist (2012), this subset does not contain temporal continuity. Indeed, the sequence of observations is not structured like it previously was. Therefore, the use of a Hidden Markov Model is not appropriate in this case.
#
# The goal of this project is thus to obtain the highest possible accuracy on this 2-class dataset. Additionnally, it should be possible to interpret the trained classifiers to understand which features are relevant and how.
#
# The proposed approach follows the standard workflow of a classification task:
# 1. Exploration of the dataset
# 2. (If necessary) Preprocessing of the dataset
# 3. Model selection between many different classifiers:
#  1. (If necessary) Hyperparameter optimization on training set with cross-validation
#  2. Evaluation of the optimal classifier on a held-out test set
#
# To increase the performance, different strategies can be used (and will be implemented if time allows):
# * dataset augmentation
# * adding more data from the original dataset
#  * use the whole 25 subjects
#  * use the whole 28 features
# * relying on unsupervised pretraining for extracting features (from raw data or precomputed features)
# * using deep architectures
# * using convolutional neural networks on EEG spectrogram
#
# These steps will be followed using [pandas](http://pandas.pydata.org/) and [scikit-learn](http://scikit-learn.org/stable/) as primary tools.

# %% [markdown]
# # 1. Exploration of the dataset

# %% [markdown]
# Let's load the data, put it in a pandas DataFrame and print a summary:

# %%
import scipy.io
import numpy as np
import pandas as pd

# %%
filepath = 'drowsy_awake_7feat.mat' # Ubuntu desktop
#filepath = 'C:\\data\\ucddb\\drowsy_awake_7feat.mat' # Windows laptop
data = scipy.io.loadmat(filepath)
    
# 'data' should contain fields 'CLASS', 'FEAT' and 'feat_names'
feat = data['FEAT']
labels = data['CLASS']
feat_names = data['feat_names']

# List comprehension for cleaning the chList
featNames_clean = [str(''.join(letter)) for letter_array in feat_names[0] for letter in letter_array]

assert (feat.shape[1] == feat_names.shape[1]), 'The number of features is not unanimous between feats and featNames.'    

# Make a pandas dataframe
feats = pd.DataFrame(data = feat, columns = featNames_clean)
feats['label'] = pd.Series(data = np.reshape(labels,(-1,)))

feats.describe()
# Out:
#           EEG_delta     EEG_theta     EEG_alpha      EEG_beta     EEG_gamma  \
# count  42570.000000  42570.000000  42570.000000  42570.000000  42570.000000
# mean      -0.478885      0.140245      0.322903      0.470606      0.544245
# std        1.007485      1.043422      0.965686      0.908886      0.947987
# min       -3.603513     -2.851259     -3.989379     -4.560769     -3.674529
# 25%       -1.217934     -0.615657     -0.266560     -0.071135     -0.062955
# 50%       -0.525052      0.054698      0.403046      0.537758      0.566928
# 75%        0.238659      0.804508      0.991577      1.075015      1.159800
# max        2.687849      4.557091      3.738396      4.362059      5.380058
#
#             EOG_std  EEG_fractal_exponent         label
# count  42570.000000          42570.000000  42570.000000
# mean       0.172083              0.628017      0.545455
# std        1.331747              0.992369      0.497935
# min       -1.399890             -3.220427      0.000000
# 25%       -0.426378             -0.044766      0.000000
# 50%       -0.203063              0.623917      1.000000
# 75%        0.257956              1.283767      1.000000
# max       20.884290              5.309254      1.000000

# %% [markdown]
# The features were most likely z-score normalized on the complete dataset, which is why the means and standard deviations are close to 0 and 1, respectively, but still slightly off. Additional normalization is thus not necessary.
#
# To get a sense of the features' distributions, we can start by plotting the corresponding boxplots:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
feats.groupby('label').boxplot(vert=False)

for i in range(7):
    ax = plt.figure()
    featName = feats.columns[i]
    feats.groupby('label')[featName].hist(alpha=0.4, bins=100)
    plt.xlabel(featName)
    plt.ylabel('Number of observations')
    plt.legend(['drowsy','awake'])
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/tools/plotting.py:2633: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Apart from EOG_std which is highly skewed to the right, the features look more or less normally distributed.
# We can observe which features are the most likely to be relevant by computing the Pearson's correlation between them and the labels:

# %%
# Correlation with the labels
plt.figure()
feats.corr()['label'].plot(kind='barh')
plt.title('Pearson correlation of the features with the labels')
plt.xlim(xmax = 1.1, xmin = -0.5);

# %% [markdown]
# EEG_fractal_exponent is the most highly correlated, while the powers in alpha and theta bands are very poorly correlated. Eventually, these two features might be dropped to simplify even further the classification task.
#
# Let's take a quick look at what these features look like in 2D:

# %%
# Scatter plot of features
colors = np.where(feats.label > 0.5, 'r', 'b')
feats.plot(kind='scatter', x='EEG_fractal_exponent', y='EEG_gamma', alpha=0.3, c=colors, s=50)
plt.legend(['drowsy','awake'])
feats.plot(kind='scatter', x='EOG_std', y='EEG_beta', alpha=0.3, c=colors, s=50)
plt.legend(['drowsy','awake'])

# %% [markdown]
# Finally, to get an idea of how variance is explained in the dataset and since it was used as a preprocessing step by the original authors, we can decompose the features using a PCA, and plot the resulting components:

# %%
from sklearn import decomposition

# %%
# Plot principal components
pca = decomposition.PCA(n_components=3)
pca.fit(feats.iloc[:,:-1])
PCs = pca.transform(feats.iloc[:,:-1])
PCs = pd.DataFrame(PCs, columns=['PC1','PC2','PC3'])
PCs['label'] = feats['label']
PCs.plot(kind='scatter', x='PC1', y='PC2', alpha=0.3, label='Drowsy', c=colors, s=50)
PCs.plot(kind='scatter', x='PC3', y='PC2', alpha=0.3, label='Drowsy', c=colors, s=50)

# Explained variance
print('Explained variance by 3 first components: %0.3f'%np.sum(pca.explained_variance_ratio_))
# Out:
# Explained variance by 3 first components: 0.847

# %% [markdown]
# The first component explains the most variance, but the second and third components seem more informative, as the difference between classes is more apparent. This is to be taken into account if PCA is used in the classification pipeline.

# %% [markdown]
# ## 2. Model evaluation

# %% [markdown]
# Since we're going to compare multiple classifiers on the same data, it is important to get an unbiased estimate of their individual accuracy. For this reason, we will split the dataset in three parts:
# 1. Training set
# 2. Validation set
# 3. Testing set
#
# To minimize the loss of training data, the first two sets will be separated using k-fold cross-validation. This will allow us to train a classifier with a set of hyperparameters on k-1 folds, and to validate it on the remaining fold (if need be). The testing set, however, will be kept unseen during the training so all classifiers can be compared. Eventually, a nested two-stage cross-validation could be done to avoid completely loosing the testing set data.
#
# Let's keep 15% of the data for testing, and divide the remaining 85% of data in 10 stratified folds (meaning that a similar percentage of observations from each class is kept in each fold).

# %%
from sklearn import cross_validation

# %%
rng = 42 # Set random number

# Separate data in train and test sets
X_train, X_test, y_train, y_test = cross_validation.train_test_split(
                                    feats.iloc[:,:-1], feats.label, test_size=0.15, random_state=rng)

# Separate train set in stratified folds for cross-validation
cv = cross_validation.StratifiedKFold(y_train, n_folds=10)

# Create a DataFrame to keep the results
clfs = np.zeros((2,10)) # row 1: validation acc. mean, row 2: test acc.

# %% [markdown]
# Before training our models, let's make a helper function that will take care of training and testing, and of displaying the results:

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.grid_search import GridSearchCV

# %%
def gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test):
    """First perform a grid search of hyperparameters contained in param_grid, then test
    on the test set. Print out some verbose and the results.
    
    Output the best trained model.
    
    Adapted from http://scikit-learn.org/stable/auto_examples/grid_search_digits.html#example-grid-search-digits-py
    """
    
    score = 'accuracy'
    
    print('# Tuning hyper-parameters for %s' %score)
    print('')

    clf = GridSearchCV(clf, param_grid, cv=cv, scoring=score, n_jobs=-1, verbose=True)
    clf.fit(X_train, y_train)

    print('Best parameters set found on development set:')
    print('')
    print(clf.best_estimator_)
    print('')
    print('Grid scores on development set:')
    print('')
    for params, mean_score, scores in clf.grid_scores_:
        print('%0.3f (+/-%0.03f) for %r'
              % (mean_score, scores.std() / 2, params))
    print('')

    print('Detailed classification report:')
    print('')
    print('The model is trained on the development set.')
    print('The scores are computed on the full test set.')
    print('')
    
    y_pred = clf.predict(X_test)
    print(classification_report(y_test, y_pred))
    print('Accuracy: %0.3f'%accuracy_score(y_test, y_pred))
    print('')
    
    # Get best model scores
    bestclf = clf.best_estimator_
    y_pred = bestclf.predict(X_train)
    train_acc = accuracy_score(y_train, y_pred)

    y_pred = bestclf.predict(X_test)
    test_acc = accuracy_score(y_test, y_pred)

    return bestclf, train_acc, test_acc

# %% [markdown]
# ### a. Random classification

# %% [markdown]
# This one is obvious, but let's start with this to see what a random classifier would give us on this dataset.

# %%
from sklearn.dummy import DummyClassifier

# %%
print('Classifier 0: Random')
print('')

# see http://scikit-learn.org/stable/auto_examples/plot_permutation_test_for_classification.html#example-plot-permutation-test-for-classification-py
randclf = DummyClassifier(strategy='uniform',random_state=rng)
randclf.fit(X_train, y_train)

y_pred = randclf.predict(X_train)
train_acc = accuracy_score(y_train, y_pred)

y_pred = randclf.predict(X_test)
test_acc = accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred))
print('Accuracy: %0.3f'%test_acc)
print('')

clfs[0,0] = train_acc
clfs[1,0] = test_acc
# Out:
# Classifier 0: Random
#
#              precision    recall  f1-score   support
#
#           0       0.45      0.50      0.48      2876
#           1       0.55      0.50      0.52      3510
#
# avg / total       0.51      0.50      0.50      6386
#
# Accuracy: 0.500

# %% [markdown]
# Unsurprisingly, this one gives us a 50% chance of guessing the right class.

# %% [markdown]
# ### b. LDA

# %% [markdown]
# Linear Discriminant Analysis is a mainstream linear classifier, especially in the world of BCIs. Knowing our features are not too far from being normally distributed, LDA should give us a good performance.
# No hyperparameters need to be optimized for this classifier, so we can use the whole training set (without cross-validation) to train it.

# %%
from sklearn import lda

# %%
print('Classifier 1: LDA')
print('')

LDAclf = lda.LDA()
LDAclf.fit(X_train, y_train)

y_pred = LDAclf.predict(X_train)
train_acc = accuracy_score(y_train, y_pred)

y_pred = LDAclf.predict(X_test)
test_acc = accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred)) 
print('Accuracy: %0.3f'%accuracy_score(y_test, y_pred))   
print('')

clfs[0,1] = train_acc
clfs[1,1] = test_acc
# Out:
# Classifier 1: LDA
#
#              precision    recall  f1-score   support
#
#           0       0.67      0.71      0.69      2876
#           1       0.75      0.71      0.73      3510
#
# avg / total       0.72      0.71      0.71      6386
#
# Accuracy: 0.713

# %% [markdown]
# Our first benchmark is 71.3%.

# %% [markdown]
# ### c. Logistic regression

# %% [markdown]
# As a second widely used linear classifier, logistic regression is more robust to outliers than LDA (which doesn't seem like a huge problem in our dataset anyway). This time, we will optimize the hyperparameter C (controlling the strength of the regularization; lower is stronger) and the type of regularization (either l1 or l2).

# %%
from sklearn import linear_model

# %%
print('Classifier 2: Logistic regression')
print('')    

clf = linear_model.LogisticRegression(random_state=rng)

param_grid = [{'C': [0.01, 0.1, 1, 10, 100], 'penalty': ['l2', 'l1']},]

bestLRclf, train_acc, test_acc = gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test)

print('')

clfs[0,2] = train_acc
clfs[1,2] = test_acc
# Out:
# Classifier 2: Logistic regression
#
# # Tuning hyper-parameters for accuracy
#
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  50 jobs       | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  86 out of 100 | elapsed:    5.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    6.5s finished
# Best parameters set found on development set:
#
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0)
#
# Grid scores on development set:
#
# 0.727 (+/-0.006) for {'penalty': 'l2', 'C': 0.01}
# 0.726 (+/-0.006) for {'penalty': 'l1', 'C': 0.01}
# 0.727 (+/-0.006) for {'penalty': 'l2', 'C': 0.1}
# 0.727 (+/-0.006) for {'penalty': 'l1', 'C': 0.1}
# 0.727 (+/-0.006) for {'penalty': 'l2', 'C': 1}
# 0.727 (+/-0.006) for {'penalty': 'l1', 'C': 1}
# 0.727 (+/-0.006) for {'penalty': 'l2', 'C': 10}
# 0.727 (+/-0.006) for {'penalty': 'l1', 'C': 10}
# 0.727 (+/-0.006) for {'penalty': 'l2', 'C': 100}
# 0.727 (+/-0.006) for {'penalty': 'l1', 'C': 100}
#
# Detailed classification report:
#
# The model is trained on the development set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.69      0.73      0.71      2876
#           1       0.77      0.72      0.75      3510
#
# avg / total       0.73      0.73      0.73      6386
#
# Accuracy: 0.728

# %% [markdown]
# Almost all models gave very similar validation accuracies (~72.7%). The best model found was the one with C=0.1 and l2-penalty, and scored 72.8% on the test set.
# Let's take a look at the coefficients for each feature:

# %%
LRcoef = pd.DataFrame(bestLRclf.coef_, columns=feats.columns[:-1])
LRcoef.T.plot(kind='barh')
plt.ylabel('LR coefficient value')

# %% [markdown]
# We expect EEG_theta and EEG_alpha coefficient values to be low because they were previously shown to be poorly correlated with the labels. Surprisingly, the coefficients learned by the logistic regression of EEG_theta and EEG_alpha rather were higher than EEG_beta and EEG_gamma, meaning they were found to be more informative by the LR.
#
# Moreover, the correlation analysis previously showed that EEG_gamma, EEG_beta and EEG_alpha are positively correlated with the labels; however, the LR found a negative weights for these features, which is counter-intuitive. Further analysis of the model might be necessary to explain this effect.

# %% [markdown]
# ### d. Linear and kernel SVMs

# %% [markdown]
# The last linear classifier we'll use is the Support Vector Machine. The kernel versions of the SVM are also very powerful, so we'll run the cross-validation over two hyperparameters:
# * C: soft margin coefficient (the higher, the more penalty is given to errors)
# * gamma: (for the RBF kernel) controls the size of the kernel
#
# The following code can take a long time to run (>60 min on a mobile i7 CPU with 2 cores) because of the cross-validation and the large amount of data (even with the tolerance parameter of the SVM training function set to 0.1).
#
# Let's start with a linear SVM:

# %%
from sklearn import svm

# %%
print('Classifier 3: Linear SVM')
print('')

clf = svm.LinearSVC(random_state=rng)

# Set up the hyperparameter search    
param_grid = [{'C': [0.1, 1, 5, 10, 25, 50, 100]}]    

bestLinearSVMclf, train_acc, test_acc = gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test)

print('')

clfs[0,3] = train_acc
clfs[1,3] = test_acc
# Out:
# Classifier 3: Linear SVM
#
# # Tuning hyper-parameters for accuracy
#
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done  50 jobs       | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:  1.5min finished
# Best parameters set found on development set:
#
# LinearSVC(C=5, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=42, tol=0.0001,
#      verbose=0)
#
# Grid scores on development set:
#
# 0.723 (+/-0.006) for {'C': 0.1}
# 0.723 (+/-0.006) for {'C': 1}
# 0.723 (+/-0.006) for {'C': 5}
# 0.722 (+/-0.005) for {'C': 10}
# 0.722 (+/-0.005) for {'C': 25}
# 0.705 (+/-0.011) for {'C': 50}
# 0.673 (+/-0.027) for {'C': 100}
#
# Detailed classification report:
#
# The model is trained on the development set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.68      0.75      0.71      2876
#           1       0.77      0.71      0.74      3510
#
# avg / total       0.73      0.73      0.73      6386
#
# Accuracy: 0.726

# %% [markdown]
# A similar performance as the best Linear Regression model is obtained for the linear SVM with C=5, at 72.6% validation accuracy. Let's take a look at the weights of this best model:

# %%
LinearSVMcoef = pd.DataFrame(bestLinearSVMclf.coef_, columns=feats.columns[:-1])
LinearSVMcoef.T.plot(kind='barh')
plt.ylabel('Linear SVM coefficient value')

# %% [markdown]
# The relative weight for each feature is very similar to what was obtained with Logistic Regression as well.
#
# Let's now try with a kernel SVM:

# %%
print('Classifier 4: Kernel SVM')
print('')

clf = svm.SVC(random_state=rng, tol=0.1)

# Set up the hyperparameter search    
param_grid = [{'C': [0.1, 1, 10, 100, 1000], 'gamma': [0.01, 0.001, 0.0001], 'kernel': ['rbf']}]    

bestKernelSVMclf, train_acc, test_acc = gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test)

print('')

clfs[0,4] = train_acc
clfs[1,4] = test_acc
# Out:
# Classifier 4: Kernel SVM
#
# # Tuning hyper-parameters for accuracy
#
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done  50 jobs       | elapsed: 10.2min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 29.6min finished
# Best parameters set found on development set:
#
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0, degree=3,
#   gamma=0.01, kernel='rbf', max_iter=-1, probability=False,
#   random_state=42, shrinking=True, tol=0.1, verbose=False)
#
# Grid scores on development set:
#
# 0.731 (+/-0.006) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.01}
# 0.702 (+/-0.006) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001}
# 0.556 (+/-0.001) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.0001}
# 0.741 (+/-0.006) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.01}
# 0.726 (+/-0.006) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.001}
# 0.701 (+/-0.006) for {'kernel': 'rbf', 'C': 1, 'gamma': 0.0001}
# 0.747 (+/-0.005) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.01}
# 0.734 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.001}
# 0.726 (+/-0.006) for {'kernel': 'rbf', 'C': 10, 'gamma': 0.0001}
# 0.754 (+/-0.006) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.01}
# 0.740 (+/-0.005) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.001}
# 0.729 (+/-0.006) for {'kernel': 'rbf', 'C': 100, 'gamma': 0.0001}
# 0.758 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.01}
# 0.744 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.001}
# 0.735 (+/-0.005) for {'kernel': 'rbf', 'C': 1000, 'gamma': 0.0001}
#
# Detailed classification report:
#
# The model is trained on the development set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.72      0.75      0.73      2876
#           1       0.79      0.76      0.78      3510
#
# avg / total       0.76      0.76      0.76      6386
#
# Accuracy: 0.756

# %% [markdown]
# The model with C=1000 and gamma=0.01 gave the best test accuracy at 75.6%. Even better results could probably be obtained by using larger C and gamma values.

# %% [markdown]
# ### e. K-nearest neighbors

# %% [markdown]
# The k-nearest neighbors algorithm is non-parametric, and can take a lot of memory since it works by remembering all the points in the dataset. However, since our dataset is low-dimensional (7 features), this is not a huge issue; additionnally, this means the curse-of-dimensionality should not be a problem.
#
# Let's try different values of k (after a few runs, I found k between 25 and 100 to usually be the best):

# %%
from sklearn import neighbors

# %%
print('Classifier 5: K-Nearest Neighbors')
print('')

clf = neighbors.KNeighborsClassifier()
param_grid = [{'n_neighbors': range(26,101,5)}] #, 'weights': ['uniform','distance']}]

bestkNNclf, train_acc, test_acc = gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test)

print('')

clfs[0,5] = train_acc
clfs[1,5] = test_acc
# Out:
# Classifier 5: K-Nearest Neighbors
#
# # Tuning hyper-parameters for accuracy
#
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  50 jobs       | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   21.4s finished
# Best parameters set found on development set:
#
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=71, p=2, weights='uniform')
#
# Grid scores on development set:
#
# 0.738 (+/-0.005) for {'n_neighbors': 26}
# 0.739 (+/-0.005) for {'n_neighbors': 31}
# 0.739 (+/-0.004) for {'n_neighbors': 36}
# 0.739 (+/-0.005) for {'n_neighbors': 41}
# 0.739 (+/-0.005) for {'n_neighbors': 46}
# 0.740 (+/-0.005) for {'n_neighbors': 51}
# 0.739 (+/-0.005) for {'n_neighbors': 56}
# 0.740 (+/-0.005) for {'n_neighbors': 61}
# 0.739 (+/-0.005) for {'n_neighbors': 66}
# 0.740 (+/-0.005) for {'n_neighbors': 71}
# 0.740 (+/-0.005) for {'n_neighbors': 76}
# 0.740 (+/-0.005) for {'n_neighbors': 81}
# 0.740 (+/-0.005) for {'n_neighbors': 86}
# 0.739 (+/-0.005) for {'n_neighbors': 91}
# 0.739 (+/-0.005) for {'n_neighbors': 96}
#
# Detailed classification report:
#
# The model is trained on the development set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.71      0.71      0.71      2876
#           1       0.77      0.76      0.76      3510
#
# avg / total       0.74      0.74      0.74      6386
#
# Accuracy: 0.740

# %% [markdown]
# The best accuracy on the test set is obtained with 71 neighbors, which yields a 74.0% accuracy.

# %% [markdown]
# ### f. Naive Bayes

# %% [markdown]
# The Naive Bayes classifier uses Bayes' rule in a simplified view where each feature is thought to be independent from the others. Even though this is an oversimplification, it has proven to be useful in many settings.
# No hyperparameters need to be tuned.

# %%
from sklearn import naive_bayes

# %%
print('Classifier 6: Naive Bayes')
print('')

clf = naive_bayes.GaussianNB()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_train)
train_acc = accuracy_score(y_train, y_pred)

y_pred = clf.predict(X_test)
test_acc = accuracy_score(y_test, y_pred)
print(classification_report(y_test, y_pred)) 
print('Accuracy: %0.3f'%accuracy_score(y_test, y_pred))   
print('')

clfs[0,6] = train_acc
clfs[1,6] = test_acc
# Out:
# Classifier 6: Naive Bayes
#
#              precision    recall  f1-score   support
#
#           0       0.61      0.79      0.69      2876
#           1       0.77      0.58      0.67      3510
#
# avg / total       0.70      0.68      0.68      6386
#
# Accuracy: 0.677

# %% [markdown]
# The accuracy is not as high as other models, with 67.7% on the test set.

# %% [markdown]
# ### g. Decision tree and Random forest

# %% [markdown]
# The straightforward interpretability of decision trees make them very useful for analyzing the relevance of the different features. Random forests is the application of ensemble methods to decision trees.

# %% [markdown]
# #### Decision tree

# %% [markdown]
# Let's start with a simple decision tree, with different values of max_depth:

# %%
from sklearn import tree

# %%
print('Classifier 7: Decision tree')
print('')

clf = tree.DecisionTreeClassifier(random_state=rng)
param_grid = [{'max_depth': [10,100,1000]}] # 'max_features': [1,2,7], 

bestDTclf, train_acc, test_acc = gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test)

print('')

clfs[0,7] = train_acc
clfs[1,7] = test_acc
# Out:
# Classifier 7: Decision tree
#
# # Tuning hyper-parameters for accuracy
#
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  16 out of  30 | elapsed:    1.6s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    2.7s finished
# Best parameters set found on development set:
#
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=10,
#             max_features=None, max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=42, splitter='best')
#
# Grid scores on development set:
#
# 0.720 (+/-0.005) for {'max_depth': 10}
# 0.656 (+/-0.003) for {'max_depth': 100}
# 0.656 (+/-0.003) for {'max_depth': 1000}
#
# Detailed classification report:
#
# The model is trained on the development set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.68      0.70      0.69      2876
#           1       0.75      0.74      0.74      3510
#
# avg / total       0.72      0.72      0.72      6386
#
# Accuracy: 0.718

# %% [markdown]
# The best model used a depth of 10 and achieved 71.8% on the test set.
#
# Let's check the importance of each feature as found by this model:

# %%
DTcoef = pd.DataFrame(np.reshape(bestDTclf.feature_importances_,(1,7)), columns=feats.columns[:-1])
DTcoef.T.plot(kind='barh')
plt.ylabel('DT feature importance value')

# %% [markdown]
# The EOG_std and EEG_fractal exponent still are the most relevant features. The other four features seem to be of a similar lower importance.
#
# It is possible to visualize the very first decisions the tree makes as a full graph using pydot and the following code. We would see that the first four decisions are made based on the values of EOG_std and EEG_fractal_exponent, as expected.

# %%
from sklearn.externals.six import StringIO  
import pydot

dot_data = StringIO() 
out = tree.export_graphviz(bestDTclf, out_file=dot_data)
graph = pydot.graph_from_dot_data(dot_data.getvalue())

print(dot_data.getvalue()[:997])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3ab7e35b21f8> in <module>()
#       4 dot_data = StringIO()
#       5 out = tree.export_graphviz(bestDTclf, out_file=dot_data)
# ----> 6 graph = pydot.graph_from_dot_data(dot_data.getvalue())
#       7
#       8 #print(dot_data.getvalue()[:997])
#
# /usr/local/lib/python2.7/dist-packages/pydot.pyc in graph_from_dot_data(data)
#     218     """
#     219
# --> 220     return dot_parser.parse_dot_data(data)
#     221
#     222
#
# NameError: global name 'dot_parser' is not defined

# %% [markdown]
# #### Random forest

# %% [markdown]
# A random forest is basically an ensemble of decision trees, with average or majority voting. The higher number of decision trees are used, the lower the variance of the model is.
#
# Increasing the number of decision trees to include (parameter n_estimators) will typically yield better performing models, but will take longer to train and evaluate, and will be heavier to store. For the sake of testing, let's try with 3 different values of n_estimators:

# %%
from sklearn import ensemble

# %%
print('Classifier 8: Random Forest')
print('')

clf = ensemble.RandomForestClassifier(random_state=rng, oob_score=True)
param_grid = [{'n_estimators': [10, 100, 300]}]

bestRFclf, train_acc, test_acc = gridSearch_thenTest(clf, param_grid, cv, X_train, y_train, X_test, y_test)

print('')

clfs[0,8] = train_acc
clfs[1,8] = test_acc
# Out:
# Classifier 8: Random Forest
#
# # Tuning hyper-parameters for accuracy
#
# Fitting 10 folds for each of 3 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Done   1 jobs       | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  1.3min finished
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# /usr/local/lib/python2.7/dist-packages/sklearn/ensemble/forest.py:378: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# Best parameters set found on development set:
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=1,
#             oob_score=True, random_state=42, verbose=0, warm_start=False)
#
# Grid scores on development set:
#
# 0.715 (+/-0.004) for {'n_estimators': 10}
# 0.738 (+/-0.004) for {'n_estimators': 100}
# 0.738 (+/-0.004) for {'n_estimators': 300}
#
# Detailed classification report:
#
# The model is trained on the development set.
# The scores are computed on the full test set.
#
#              precision    recall  f1-score   support
#
#           0       0.72      0.71      0.72      2876
#           1       0.77      0.77      0.77      3510
#
# avg / total       0.74      0.74      0.74      6386
#
# Accuracy: 0.744

# %% [markdown]
# The RF with 300 estimators gives the best test accuracy, with 74.4%. Let's explore the model a little bit.
#
# First, let's look at the importance of features averaged over all the trees:

# %%
RFcoef = pd.DataFrame(np.reshape(bestRFclf.feature_importances_,(1,7)), columns=feats.columns[:-1])
RFcoef.T.plot(kind='barh')
plt.ylabel('RF feature importance value')

# %% [markdown]
# Although EOG_std and EEG_fractal_exponent are still the highest ranked features, the higher relative importance of band power features shows the random forest was able to use them and gain better accuracy.

# %% [markdown]
# ### h. Neural network

# %% [markdown]
# As a last classifier, let's try a fully connected, feedforward Neural Network. We'll use the [keras](http://keras.io/) neural network library to train a 4-layer model with dropout, momentum and ReLU activation units for 100 epochs, with a minibatch size of 64. Since training takes some time on a CPU, we won't optimize the hyperparameters and will train on the whole training set (no cross-validation) and test the performance on the test set.

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
from keras.utils import np_utils

# %%
print('Classifier 9: Neural Network')
print('')

batch_size = 64
nb_classes = 2
nb_epoch = 100

np.random.seed(42)

X_train_NN = X_train.astype('float32').values
X_test_NN = X_test.astype('float32').values
print(X_train_NN.shape[0], 'train samples')
print(X_test_NN.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train_NN = np_utils.to_categorical(y_train, nb_classes)
y_test_NN = np_utils.to_categorical(y_test, nb_classes)

model = Sequential()
model.add(Dense(X_train_NN.shape[1], 128))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(128, 128))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(128, 128))
model.add(Activation('relu'))
model.add(Dropout(0.2))

model.add(Dense(128, 2))
model.add(Activation('softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd)

model.fit(X_train_NN, y_train_NN, batch_size=batch_size, nb_epoch=nb_epoch, show_accuracy=True, verbose=1,
         validation_data=(X_test_NN, y_test_NN))
test_score = model.evaluate(X_test_NN, y_test_NN, show_accuracy=True, verbose=0)
train_score = model.evaluate(X_train_NN, y_train_NN, show_accuracy=True, verbose=0)
print('Test score:', test_score[0])
print('Test accuracy:', test_score[1])

clfs[0,9] = train_score[1]
clfs[1,9] = test_score[1]
# Out:
# Classifier 9: Neural Network
#
# (36184, 'train samples')
# (6386, 'test samples')
# Train on 36184 samples, validate on 6386 samples
# Epoch 0
# Epoch 0
# 36184/36184 [==============================] - 2s - loss: 0.6013 - acc.: 0.6710 - val. loss: 0.5529 - val. acc.: 0.7344
# 36184/36184 [==============================] - 2s - loss: 0.6013 - acc.: 0.6710 - val. loss: 0.5529 - val. acc.: 0.7344
# Epoch 1
# Epoch 1
# 36184/36184 [==============================] - 2s - loss: 0.5505 - acc.: 0.7287 - val. loss: 0.5355 - val. acc.: 0.7371
# 36184/36184 [==============================] - 2s - loss: 0.5505 - acc.: 0.7287 - val. loss: 0.5355 - val. acc.: 0.7371
# Epoch 2
# Epoch 2
# 36184/36184 [==============================] - 2s - loss: 0.5411 - acc.: 0.7343 - val. loss: 0.5334 - val. acc.: 0.7313
# 36184/36184 [==============================] - 2s - loss: 0.5411 - acc.: 0.7343 - val. loss: 0.5334 - val. acc.: 0.7313
# Epoch 3
# Epoch 3
# 36184/36184 [==============================] - 1s - loss: 0.5360 - acc.: 0.7370 - val. loss: 0.5267 - val. acc.: 0.7380
# 36184/36184 [==============================] - 1s - loss: 0.5360 - acc.: 0.7370 - val. loss: 0.5267 - val. acc.: 0.7380
# Epoch 4
# Epoch 4
# 36184/36184 [==============================] - 1s - loss: 0.5337 - acc.: 0.7376 - val. loss: 0.5245 - val. acc.: 0.7407
# 36184/36184 [==============================] - 1s - loss: 0.5337 - acc.: 0.7376 - val. loss: 0.5245 - val. acc.: 0.7407
# Epoch 5
# Epoch 5
# 36184/36184 [==============================] - 1s - loss: 0.5324 - acc.: 0.7403 - val. loss: 0.5335 - val. acc.: 0.7330
# 36184/36184 [==============================] - 1s - loss: 0.5324 - acc.: 0.7403 - val. loss: 0.5335 - val. acc.: 0.7330
# Epoch 6
# Epoch 6
# 36184/36184 [==============================] - 1s - loss: 0.5304 - acc.: 0.7407 - val. loss: 0.5267 - val. acc.: 0.7380
# 36184/36184 [==============================] - 1s - loss: 0.5304 - acc.: 0.7407 - val. loss: 0.5267 - val. acc.: 0.7380
# Epoch 7
# Epoch 7
# 36184/36184 [==============================] - 1s - loss: 0.5284 - acc.: 0.7405 - val. loss: 0.5192 - val. acc.: 0.7448
# 36184/36184 [==============================] - 1s - loss: 0.5284 - acc.: 0.7405 - val. loss: 0.5192 - val. acc.: 0.7448
# Epoch 8
# Epoch 8
# 36184/36184 [==============================] - 1s - loss: 0.5268 - acc.: 0.7436 - val. loss: 0.5179 - val. acc.: 0.7448
# 36184/36184 [==============================] - 1s - loss: 0.5268 - acc.: 0.7436 - val. loss: 0.5179 - val. acc.: 0.7448
# Epoch 9
# Epoch 9
# 36184/36184 [==============================] - 2s - loss: 0.5246 - acc.: 0.7435 - val. loss: 0.5165 - val. acc.: 0.7449
# 36184/36184 [==============================] - 2s - loss: 0.5246 - acc.: 0.7435 - val. loss: 0.5165 - val. acc.: 0.7449
# Epoch 10
# Epoch 10
# 36184/36184 [==============================] - 2s - loss: 0.5240 - acc.: 0.7423 - val. loss: 0.5146 - val. acc.: 0.7454
# 36184/36184 [==============================] - 2s - loss: 0.5240 - acc.: 0.7423 - val. loss: 0.5146 - val. acc.: 0.7454
# Epoch 11
# Epoch 11
# 36184/36184 [==============================] - 2s - loss: 0.5197 - acc.: 0.7465 - val. loss: 0.5150 - val. acc.: 0.7477
# 36184/36184 [==============================] - 2s - loss: 0.5197 - acc.: 0.7465 - val. loss: 0.5150 - val. acc.: 0.7477
# Epoch 12
# Epoch 12
# 36184/36184 [==============================] - 2s - loss: 0.5201 - acc.: 0.7446 - val. loss: 0.5152 - val. acc.: 0.7477
# 36184/36184 [==============================] - 2s - loss: 0.5201 - acc.: 0.7446 - val. loss: 0.5152 - val. acc.: 0.7477
# Epoch 13
# Epoch 13
# 36184/36184 [==============================] - 2s - loss: 0.5186 - acc.: 0.7476 - val. loss: 0.5138 - val. acc.: 0.7443
# 36184/36184 [==============================] - 2s - loss: 0.5186 - acc.: 0.7476 - val. loss: 0.5138 - val. acc.: 0.7443
# Epoch 14
# Epoch 14
# 36184/36184 [==============================] - 1s - loss: 0.5183 - acc.: 0.7488 - val. loss: 0.5091 - val. acc.: 0.7487
# 36184/36184 [==============================] - 1s - loss: 0.5183 - acc.: 0.7488 - val. loss: 0.5091 - val. acc.: 0.7487
# Epoch 15
# Epoch 15
# 36184/36184 [==============================] - 2s - loss: 0.5164 - acc.: 0.7498 - val. loss: 0.5089 - val. acc.: 0.7527
# 36184/36184 [==============================] - 2s - loss: 0.5164 - acc.: 0.7498 - val. loss: 0.5089 - val. acc.: 0.7527
# Epoch 16
# Epoch 16
# 36184/36184 [==============================] - 2s - loss: 0.5160 - acc.: 0.7494 - val. loss: 0.5086 - val. acc.: 0.7501
# 36184/36184 [==============================] - 2s - loss: 0.5160 - acc.: 0.7494 - val. loss: 0.5086 - val. acc.: 0.7501
# Epoch 17
# Epoch 17
# 36184/36184 [==============================] - 1s - loss: 0.5144 - acc.: 0.7510 - val. loss: 0.5102 - val. acc.: 0.7565
# 36184/36184 [==============================] - 1s - loss: 0.5144 - acc.: 0.7510 - val. loss: 0.5102 - val. acc.: 0.7565
# Epoch 18
# Epoch 18
# 36184/36184 [==============================] - 1s - loss: 0.5136 - acc.: 0.7523 - val. loss: 0.5092 - val. acc.: 0.7549
# 36184/36184 [==============================] - 1s - loss: 0.5136 - acc.: 0.7523 - val. loss: 0.5092 - val. acc.: 0.7549
# Epoch 19
# Epoch 19
# 36184/36184 [==============================] - 1s - loss: 0.5136 - acc.: 0.7503 - val. loss: 0.5113 - val. acc.: 0.7455
# 36184/36184 [==============================] - 1s - loss: 0.5136 - acc.: 0.7503 - val. loss: 0.5113 - val. acc.: 0.7455
# Epoch 20
# Epoch 20
# 36184/36184 [==============================] - 2s - loss: 0.5124 - acc.: 0.7515 - val. loss: 0.5113 - val. acc.: 0.7529
# 36184/36184 [==============================] - 2s - loss: 0.5124 - acc.: 0.7515 - val. loss: 0.5113 - val. acc.: 0.7529
# Epoch 21
# Epoch 21
# 36184/36184 [==============================] - 1s - loss: 0.5114 - acc.: 0.7517 - val. loss: 0.5037 - val. acc.: 0.7535
# 36184/36184 [==============================] - 1s - loss: 0.5114 - acc.: 0.7517 - val. loss: 0.5037 - val. acc.: 0.7535
# Epoch 22
# Epoch 22
# 36184/36184 [==============================] - 2s - loss: 0.5107 - acc.: 0.7519 - val. loss: 0.5076 - val. acc.: 0.7479
# 36184/36184 [==============================] - 2s - loss: 0.5107 - acc.: 0.7519 - val. loss: 0.5076 - val. acc.: 0.7479
# Epoch 23
# Epoch 23
# 36184/36184 [==============================] - 1s - loss: 0.5083 - acc.: 0.7563 - val. loss: 0.5055 - val. acc.: 0.7538
# 36184/36184 [==============================] - 1s - loss: 0.5083 - acc.: 0.7563 - val. loss: 0.5055 - val. acc.: 0.7538
# Epoch 24
# Epoch 24
# 36184/36184 [==============================] - 1s - loss: 0.5093 - acc.: 0.7533 - val. loss: 0.5037 - val. acc.: 0.7552
# 36184/36184 [==============================] - 1s - loss: 0.5093 - acc.: 0.7533 - val. loss: 0.5037 - val. acc.: 0.7552
# Epoch 25
# Epoch 25
# 36184/36184 [==============================] - 1s - loss: 0.5083 - acc.: 0.7542 - val. loss: 0.5021 - val. acc.: 0.7570
# 36184/36184 [==============================] - 1s - loss: 0.5083 - acc.: 0.7542 - val. loss: 0.5021 - val. acc.: 0.7570
# Epoch 26
# Epoch 26
# 36184/36184 [==============================] - 2s - loss: 0.5070 - acc.: 0.7561 - val. loss: 0.5021 - val. acc.: 0.7563
# 36184/36184 [==============================] - 2s - loss: 0.5070 - acc.: 0.7561 - val. loss: 0.5021 - val. acc.: 0.7563
# Epoch 27
# Epoch 27
# 36184/36184 [==============================] - 2s - loss: 0.5080 - acc.: 0.7550 - val. loss: 0.5043 - val. acc.: 0.7549
# 36184/36184 [==============================] - 2s - loss: 0.5080 - acc.: 0.7550 - val. loss: 0.5043 - val. acc.: 0.7549
# Epoch 28
# Epoch 28
# 36184/36184 [==============================] - 1s - loss: 0.5067 - acc.: 0.7551 - val. loss: 0.5013 - val. acc.: 0.7551
# 36184/36184 [==============================] - 1s - loss: 0.5067 - acc.: 0.7551 - val. loss: 0.5013 - val. acc.: 0.7551
# Epoch 29
# Epoch 29
# 36184/36184 [==============================] - 1s - loss: 0.5076 - acc.: 0.7553 - val. loss: 0.5063 - val. acc.: 0.7521
# 36184/36184 [==============================] - 1s - loss: 0.5076 - acc.: 0.7553 - val. loss: 0.5063 - val. acc.: 0.7521
# Epoch 30
# Epoch 30
# 36184/36184 [==============================] - 1s - loss: 0.5066 - acc.: 0.7555 - val. loss: 0.5004 - val. acc.: 0.7559
# 36184/36184 [==============================] - 1s - loss: 0.5066 - acc.: 0.7555 - val. loss: 0.5004 - val. acc.: 0.7559
# Epoch 31
# Epoch 31
# 36184/36184 [==============================] - 1s - loss: 0.5059 - acc.: 0.7566 - val. loss: 0.5006 - val. acc.: 0.7559
# 36184/36184 [==============================] - 1s - loss: 0.5059 - acc.: 0.7566 - val. loss: 0.5006 - val. acc.: 0.7559
# Epoch 32
# Epoch 32
# 36184/36184 [==============================] - 1s - loss: 0.5059 - acc.: 0.7564 - val. loss: 0.5003 - val. acc.: 0.7581
# 36184/36184 [==============================] - 1s - loss: 0.5059 - acc.: 0.7564 - val. loss: 0.5003 - val. acc.: 0.7581
# Epoch 33
# Epoch 33
# 36184/36184 [==============================] - 1s - loss: 0.5056 - acc.: 0.7551 - val. loss: 0.4987 - val. acc.: 0.7599
# 36184/36184 [==============================] - 1s - loss: 0.5056 - acc.: 0.7551 - val. loss: 0.4987 - val. acc.: 0.7599
# Epoch 34
# Epoch 34
# 36184/36184 [==============================] - 1s - loss: 0.5043 - acc.: 0.7576 - val. loss: 0.5008 - val. acc.: 0.7606
# 36184/36184 [==============================] - 1s - loss: 0.5043 - acc.: 0.7576 - val. loss: 0.5008 - val. acc.: 0.7606
# Epoch 35
# Epoch 35
# 36184/36184 [==============================] - 1s - loss: 0.5040 - acc.: 0.7572 - val. loss: 0.4998 - val. acc.: 0.7584
# 36184/36184 [==============================] - 1s - loss: 0.5040 - acc.: 0.7572 - val. loss: 0.4998 - val. acc.: 0.7584
# Epoch 36
# Epoch 36
# 36184/36184 [==============================] - 1s - loss: 0.5042 - acc.: 0.7586 - val. loss: 0.4986 - val. acc.: 0.7587
# 36184/36184 [==============================] - 1s - loss: 0.5042 - acc.: 0.7586 - val. loss: 0.4986 - val. acc.: 0.7587
# Epoch 37
# Epoch 37
# 36184/36184 [==============================] - 1s - loss: 0.5033 - acc.: 0.7587 - val. loss: 0.4992 - val. acc.: 0.7585
# 36184/36184 [==============================] - 1s - loss: 0.5033 - acc.: 0.7587 - val. loss: 0.4992 - val. acc.: 0.7585
# Epoch 38
# Epoch 38
# 36184/36184 [==============================] - 2s - loss: 0.5023 - acc.: 0.7580 - val. loss: 0.4991 - val. acc.: 0.7565
# 36184/36184 [==============================] - 2s - loss: 0.5023 - acc.: 0.7580 - val. loss: 0.4991 - val. acc.: 0.7565
# Epoch 39
# Epoch 39
# 36184/36184 [==============================] - 1s - loss: 0.5028 - acc.: 0.7579 - val. loss: 0.4978 - val. acc.: 0.7587
# 36184/36184 [==============================] - 1s - loss: 0.5028 - acc.: 0.7579 - val. loss: 0.4978 - val. acc.: 0.7587
# Epoch 40
# Epoch 40
# 36184/36184 [==============================] - 1s - loss: 0.5041 - acc.: 0.7588 - val. loss: 0.4976 - val. acc.: 0.7603
# 36184/36184 [==============================] - 1s - loss: 0.5041 - acc.: 0.7588 - val. loss: 0.4976 - val. acc.: 0.7603
# Epoch 41
# Epoch 41
# 36184/36184 [==============================] - 1s - loss: 0.5024 - acc.: 0.7587 - val. loss: 0.4983 - val. acc.: 0.7571
# 36184/36184 [==============================] - 1s - loss: 0.5024 - acc.: 0.7587 - val. loss: 0.4983 - val. acc.: 0.7571
# Epoch 42
# Epoch 42
# 36184/36184 [==============================] - 1s - loss: 0.5027 - acc.: 0.7580 - val. loss: 0.4979 - val. acc.: 0.7567
# 36184/36184 [==============================] - 1s - loss: 0.5027 - acc.: 0.7580 - val. loss: 0.4979 - val. acc.: 0.7567
# Epoch 43
# Epoch 43
# 36184/36184 [==============================] - 1s - loss: 0.5015 - acc.: 0.7592 - val. loss: 0.5006 - val. acc.: 0.7576
# 36184/36184 [==============================] - 1s - loss: 0.5015 - acc.: 0.7592 - val. loss: 0.5006 - val. acc.: 0.7576
# Epoch 44
# Epoch 44
# 36184/36184 [==============================] - 1s - loss: 0.5022 - acc.: 0.7595 - val. loss: 0.4970 - val. acc.: 0.7637
# 36184/36184 [==============================] - 1s - loss: 0.5022 - acc.: 0.7595 - val. loss: 0.4970 - val. acc.: 0.7637
# Epoch 45
# Epoch 45
# 36184/36184 [==============================] - 1s - loss: 0.5017 - acc.: 0.7599 - val. loss: 0.4990 - val. acc.: 0.7546
# 36184/36184 [==============================] - 1s - loss: 0.5017 - acc.: 0.7599 - val. loss: 0.4990 - val. acc.: 0.7546
# Epoch 46
# Epoch 46
# 36184/36184 [==============================] - 1s - loss: 0.5022 - acc.: 0.7576 - val. loss: 0.4998 - val. acc.: 0.7607
# 36184/36184 [==============================] - 1s - loss: 0.5022 - acc.: 0.7576 - val. loss: 0.4998 - val. acc.: 0.7607
# Epoch 47
# Epoch 47
# 36184/36184 [==============================] - 1s - loss: 0.5017 - acc.: 0.7587 - val. loss: 0.4964 - val. acc.: 0.7587
# 36184/36184 [==============================] - 1s - loss: 0.5017 - acc.: 0.7587 - val. loss: 0.4964 - val. acc.: 0.7587
# Epoch 48
# Epoch 48
# 36184/36184 [==============================] - 1s - loss: 0.5013 - acc.: 0.7584 - val. loss: 0.4984 - val. acc.: 0.7578
# 36184/36184 [==============================] - 1s - loss: 0.5013 - acc.: 0.7584 - val. loss: 0.4984 - val. acc.: 0.7578
# Epoch 49
# Epoch 49
# 36184/36184 [==============================] - 1s - loss: 0.4999 - acc.: 0.7586 - val. loss: 0.5002 - val. acc.: 0.7534
# 36184/36184 [==============================] - 1s - loss: 0.4999 - acc.: 0.7586 - val. loss: 0.5002 - val. acc.: 0.7534
# Epoch 50
# Epoch 50
# 36184/36184 [==============================] - 1s - loss: 0.4991 - acc.: 0.7595 - val. loss: 0.4992 - val. acc.: 0.7620
# 36184/36184 [==============================] - 1s - loss: 0.4991 - acc.: 0.7595 - val. loss: 0.4992 - val. acc.: 0.7620
# Epoch 51
# Epoch 51
# 36184/36184 [==============================] - 1s - loss: 0.4990 - acc.: 0.7604 - val. loss: 0.5007 - val. acc.: 0.7551
# 36184/36184 [==============================] - 1s - loss: 0.4990 - acc.: 0.7604 - val. loss: 0.5007 - val. acc.: 0.7551
# Epoch 52
# Epoch 52
# 36184/36184 [==============================] - 1s - loss: 0.4993 - acc.: 0.7606 - val. loss: 0.4972 - val. acc.: 0.7570
# 36184/36184 [==============================] - 1s - loss: 0.4993 - acc.: 0.7606 - val. loss: 0.4972 - val. acc.: 0.7570
# Epoch 53
# Epoch 53
# 36184/36184 [==============================] - 1s - loss: 0.4992 - acc.: 0.7621 - val. loss: 0.4966 - val. acc.: 0.7563
# 36184/36184 [==============================] - 1s - loss: 0.4992 - acc.: 0.7621 - val. loss: 0.4966 - val. acc.: 0.7563
# Epoch 54
# Epoch 54
# 36184/36184 [==============================] - 1s - loss: 0.4990 - acc.: 0.7610 - val. loss: 0.4956 - val. acc.: 0.7576
# 36184/36184 [==============================] - 1s - loss: 0.4990 - acc.: 0.7610 - val. loss: 0.4956 - val. acc.: 0.7576
# Epoch 55
# Epoch 55
# 36184/36184 [==============================] - 1s - loss: 0.5000 - acc.: 0.7609 - val. loss: 0.4957 - val. acc.: 0.7570
# 36184/36184 [==============================] - 1s - loss: 0.5000 - acc.: 0.7609 - val. loss: 0.4957 - val. acc.: 0.7570
# Epoch 56
# Epoch 56
# 36184/36184 [==============================] - 1s - loss: 0.4980 - acc.: 0.7618 - val. loss: 0.5041 - val. acc.: 0.7541
# 36184/36184 [==============================] - 1s - loss: 0.4980 - acc.: 0.7618 - val. loss: 0.5041 - val. acc.: 0.7541
# Epoch 57
# Epoch 57
# 36184/36184 [==============================] - 1s - loss: 0.4984 - acc.: 0.7605 - val. loss: 0.4980 - val. acc.: 0.7612
# 36184/36184 [==============================] - 1s - loss: 0.4984 - acc.: 0.7605 - val. loss: 0.4980 - val. acc.: 0.7612
# Epoch 58
# Epoch 58
# 36184/36184 [==============================] - 1s - loss: 0.4991 - acc.: 0.7605 - val. loss: 0.4941 - val. acc.: 0.7556
# 36184/36184 [==============================] - 1s - loss: 0.4991 - acc.: 0.7605 - val. loss: 0.4941 - val. acc.: 0.7556
# Epoch 59
# Epoch 59
# 36184/36184 [==============================] - 1s - loss: 0.4975 - acc.: 0.7598 - val. loss: 0.4954 - val. acc.: 0.7599
# 36184/36184 [==============================] - 1s - loss: 0.4975 - acc.: 0.7598 - val. loss: 0.4954 - val. acc.: 0.7599
# Epoch 60
# Epoch 60
# 36184/36184 [==============================] - 1s - loss: 0.4980 - acc.: 0.7603 - val. loss: 0.4967 - val. acc.: 0.7573
# 36184/36184 [==============================] - 1s - loss: 0.4980 - acc.: 0.7603 - val. loss: 0.4967 - val. acc.: 0.7573
# Epoch 61
# Epoch 61
# 36184/36184 [==============================] - 1s - loss: 0.4975 - acc.: 0.7625 - val. loss: 0.4941 - val. acc.: 0.7601
# 36184/36184 [==============================] - 1s - loss: 0.4975 - acc.: 0.7625 - val. loss: 0.4941 - val. acc.: 0.7601
# Epoch 62
# Epoch 62
# 36184/36184 [==============================] - 1s - loss: 0.4970 - acc.: 0.7629 - val. loss: 0.5033 - val. acc.: 0.7543
# 36184/36184 [==============================] - 1s - loss: 0.4970 - acc.: 0.7629 - val. loss: 0.5033 - val. acc.: 0.7543
# Epoch 63
# Epoch 63
# 36184/36184 [==============================] - 1s - loss: 0.4977 - acc.: 0.7616 - val. loss: 0.5050 - val. acc.: 0.7546
# 36184/36184 [==============================] - 1s - loss: 0.4977 - acc.: 0.7616 - val. loss: 0.5050 - val. acc.: 0.7546
# Epoch 64
# Epoch 64
# 36184/36184 [==============================] - 1s - loss: 0.4968 - acc.: 0.7608 - val. loss: 0.4946 - val. acc.: 0.7584
# 36184/36184 [==============================] - 1s - loss: 0.4968 - acc.: 0.7608 - val. loss: 0.4946 - val. acc.: 0.7584
# Epoch 65
# Epoch 65
# 36184/36184 [==============================] - 1s - loss: 0.4976 - acc.: 0.7584 - val. loss: 0.4945 - val. acc.: 0.7587
# 36184/36184 [==============================] - 1s - loss: 0.4976 - acc.: 0.7584 - val. loss: 0.4945 - val. acc.: 0.7587
# Epoch 66
# Epoch 66
# 36184/36184 [==============================] - 2s - loss: 0.4975 - acc.: 0.7617 - val. loss: 0.4953 - val. acc.: 0.7562
# 36184/36184 [==============================] - 2s - loss: 0.4975 - acc.: 0.7617 - val. loss: 0.4953 - val. acc.: 0.7562
# Epoch 67
# Epoch 67
# 36184/36184 [==============================] - 2s - loss: 0.4950 - acc.: 0.7626 - val. loss: 0.4937 - val. acc.: 0.7599
# 36184/36184 [==============================] - 2s - loss: 0.4950 - acc.: 0.7626 - val. loss: 0.4937 - val. acc.: 0.7599
# Epoch 68
# Epoch 68
# 36184/36184 [==============================] - 1s - loss: 0.4957 - acc.: 0.7635 - val. loss: 0.4924 - val. acc.: 0.7579
# 36184/36184 [==============================] - 1s - loss: 0.4957 - acc.: 0.7635 - val. loss: 0.4924 - val. acc.: 0.7579
# Epoch 69
# Epoch 69
# 36184/36184 [==============================] - 1s - loss: 0.4956 - acc.: 0.7627 - val. loss: 0.4949 - val. acc.: 0.7614
# 36184/36184 [==============================] - 1s - loss: 0.4956 - acc.: 0.7627 - val. loss: 0.4949 - val. acc.: 0.7614
# Epoch 70
# Epoch 70
# 36184/36184 [==============================] - 1s - loss: 0.4961 - acc.: 0.7644 - val. loss: 0.4927 - val. acc.: 0.7592
# 36184/36184 [==============================] - 1s - loss: 0.4961 - acc.: 0.7644 - val. loss: 0.4927 - val. acc.: 0.7592
# Epoch 71
# Epoch 71
# 36184/36184 [==============================] - 1s - loss: 0.4954 - acc.: 0.7624 - val. loss: 0.4919 - val. acc.: 0.7584
# 36184/36184 [==============================] - 1s - loss: 0.4954 - acc.: 0.7624 - val. loss: 0.4919 - val. acc.: 0.7584
# Epoch 72
# Epoch 72
# 36184/36184 [==============================] - 2s - loss: 0.4955 - acc.: 0.7620 - val. loss: 0.4931 - val. acc.: 0.7606
# 36184/36184 [==============================] - 2s - loss: 0.4955 - acc.: 0.7620 - val. loss: 0.4931 - val. acc.: 0.7606
# Epoch 73
# Epoch 73
# 36184/36184 [==============================] - 2s - loss: 0.4951 - acc.: 0.7629 - val. loss: 0.4933 - val. acc.: 0.7581
# 36184/36184 [==============================] - 2s - loss: 0.4951 - acc.: 0.7629 - val. loss: 0.4933 - val. acc.: 0.7581
# Epoch 74
# Epoch 74
# 36184/36184 [==============================] - 2s - loss: 0.4952 - acc.: 0.7631 - val. loss: 0.4942 - val. acc.: 0.7576
# 36184/36184 [==============================] - 2s - loss: 0.4952 - acc.: 0.7631 - val. loss: 0.4942 - val. acc.: 0.7576
# Epoch 75
# Epoch 75
# 36184/36184 [==============================] - 1s - loss: 0.4937 - acc.: 0.7631 - val. loss: 0.4914 - val. acc.: 0.7612
# 36184/36184 [==============================] - 1s - loss: 0.4937 - acc.: 0.7631 - val. loss: 0.4914 - val. acc.: 0.7612
# Epoch 76
# Epoch 76
# 36184/36184 [==============================] - 1s - loss: 0.4949 - acc.: 0.7624 - val. loss: 0.5016 - val. acc.: 0.7529
# 36184/36184 [==============================] - 1s - loss: 0.4949 - acc.: 0.7624 - val. loss: 0.5016 - val. acc.: 0.7529
# Epoch 77
# Epoch 77
# 36184/36184 [==============================] - 1s - loss: 0.4937 - acc.: 0.7629 - val. loss: 0.4906 - val. acc.: 0.7578
# 36184/36184 [==============================] - 1s - loss: 0.4937 - acc.: 0.7629 - val. loss: 0.4906 - val. acc.: 0.7578
# Epoch 78
# Epoch 78
# 36184/36184 [==============================] - 1s - loss: 0.4934 - acc.: 0.7640 - val. loss: 0.4971 - val. acc.: 0.7585
# 36184/36184 [==============================] - 1s - loss: 0.4934 - acc.: 0.7640 - val. loss: 0.4971 - val. acc.: 0.7585
# Epoch 79
# Epoch 79
# 36184/36184 [==============================] - 1s - loss: 0.4945 - acc.: 0.7652 - val. loss: 0.4925 - val. acc.: 0.7590
# 36184/36184 [==============================] - 1s - loss: 0.4945 - acc.: 0.7652 - val. loss: 0.4925 - val. acc.: 0.7590
# Epoch 80
# Epoch 80
# 36184/36184 [==============================] - 1s - loss: 0.4928 - acc.: 0.7642 - val. loss: 0.4942 - val. acc.: 0.7637
# 36184/36184 [==============================] - 1s - loss: 0.4928 - acc.: 0.7642 - val. loss: 0.4942 - val. acc.: 0.7637
# Epoch 81
# Epoch 81
# 36184/36184 [==============================] - 1s - loss: 0.4933 - acc.: 0.7658 - val. loss: 0.4909 - val. acc.: 0.7601
# 36184/36184 [==============================] - 1s - loss: 0.4933 - acc.: 0.7658 - val. loss: 0.4909 - val. acc.: 0.7601
# Epoch 82
# Epoch 82
# 36184/36184 [==============================] - 1s - loss: 0.4937 - acc.: 0.7650 - val. loss: 0.4915 - val. acc.: 0.7607
# 36184/36184 [==============================] - 1s - loss: 0.4937 - acc.: 0.7650 - val. loss: 0.4915 - val. acc.: 0.7607
# Epoch 83
# Epoch 83
# 36184/36184 [==============================] - 2s - loss: 0.4926 - acc.: 0.7641 - val. loss: 0.4905 - val. acc.: 0.7609
# 36184/36184 [==============================] - 2s - loss: 0.4926 - acc.: 0.7641 - val. loss: 0.4905 - val. acc.: 0.7609
# Epoch 84
# Epoch 84
# 36184/36184 [==============================] - 2s - loss: 0.4923 - acc.: 0.7653 - val. loss: 0.4913 - val. acc.: 0.7601
# 36184/36184 [==============================] - 2s - loss: 0.4923 - acc.: 0.7653 - val. loss: 0.4913 - val. acc.: 0.7601
# Epoch 85
# Epoch 85
# 36184/36184 [==============================] - 2s - loss: 0.4923 - acc.: 0.7659 - val. loss: 0.4962 - val. acc.: 0.7574
# 36184/36184 [==============================] - 2s - loss: 0.4923 - acc.: 0.7659 - val. loss: 0.4962 - val. acc.: 0.7574
# Epoch 86
# Epoch 86
# 36184/36184 [==============================] - 2s - loss: 0.4921 - acc.: 0.7654 - val. loss: 0.4954 - val. acc.: 0.7562
# 36184/36184 [==============================] - 2s - loss: 0.4921 - acc.: 0.7654 - val. loss: 0.4954 - val. acc.: 0.7562
# Epoch 87
# Epoch 87
# 36184/36184 [==============================] - 1s - loss: 0.4924 - acc.: 0.7645 - val. loss: 0.4921 - val. acc.: 0.7595
# 36184/36184 [==============================] - 1s - loss: 0.4924 - acc.: 0.7645 - val. loss: 0.4921 - val. acc.: 0.7595
# Epoch 88
# Epoch 88
# 36184/36184 [==============================] - 1s - loss: 0.4919 - acc.: 0.7656 - val. loss: 0.4922 - val. acc.: 0.7588
# 36184/36184 [==============================] - 1s - loss: 0.4919 - acc.: 0.7656 - val. loss: 0.4922 - val. acc.: 0.7588
# Epoch 89
# Epoch 89
# 36184/36184 [==============================] - 1s - loss: 0.4921 - acc.: 0.7650 - val. loss: 0.4913 - val. acc.: 0.7585
# 36184/36184 [==============================] - 1s - loss: 0.4921 - acc.: 0.7650 - val. loss: 0.4913 - val. acc.: 0.7585
# Epoch 90
# Epoch 90
# 36184/36184 [==============================] - 1s - loss: 0.4912 - acc.: 0.7650 - val. loss: 0.4911 - val. acc.: 0.7598
# 36184/36184 [==============================] - 1s - loss: 0.4912 - acc.: 0.7650 - val. loss: 0.4911 - val. acc.: 0.7598
# Epoch 91
# Epoch 91
# 36184/36184 [==============================] - 1s - loss: 0.4916 - acc.: 0.7676 - val. loss: 0.4901 - val. acc.: 0.7604
# 36184/36184 [==============================] - 1s - loss: 0.4916 - acc.: 0.7676 - val. loss: 0.4901 - val. acc.: 0.7604
# Epoch 92
# Epoch 92
# 36184/36184 [==============================] - 1s - loss: 0.4913 - acc.: 0.7646 - val. loss: 0.4909 - val. acc.: 0.7604
# 36184/36184 [==============================] - 1s - loss: 0.4913 - acc.: 0.7646 - val. loss: 0.4909 - val. acc.: 0.7604
# Epoch 93
# Epoch 93
# 36184/36184 [==============================] - 1s - loss: 0.4890 - acc.: 0.7673 - val. loss: 0.4895 - val. acc.: 0.7585
# 36184/36184 [==============================] - 1s - loss: 0.4890 - acc.: 0.7673 - val. loss: 0.4895 - val. acc.: 0.7585
# Epoch 94
# Epoch 94
# 36184/36184 [==============================] - 1s - loss: 0.4914 - acc.: 0.7672 - val. loss: 0.4892 - val. acc.: 0.7614
# 36184/36184 [==============================] - 1s - loss: 0.4914 - acc.: 0.7672 - val. loss: 0.4892 - val. acc.: 0.7614
# Epoch 95
# Epoch 95
# 36184/36184 [==============================] - 2s - loss: 0.4913 - acc.: 0.7648 - val. loss: 0.4913 - val. acc.: 0.7596
# 36184/36184 [==============================] - 2s - loss: 0.4913 - acc.: 0.7648 - val. loss: 0.4913 - val. acc.: 0.7596
# Epoch 96
# Epoch 96
# 36184/36184 [==============================] - 2s - loss: 0.4917 - acc.: 0.7649 - val. loss: 0.4898 - val. acc.: 0.7615
# 36184/36184 [==============================] - 2s - loss: 0.4917 - acc.: 0.7649 - val. loss: 0.4898 - val. acc.: 0.7615
# Epoch 97
# Epoch 97
# 36184/36184 [==============================] - 1s - loss: 0.4902 - acc.: 0.7660 - val. loss: 0.4897 - val. acc.: 0.7620
# 36184/36184 [==============================] - 1s - loss: 0.4902 - acc.: 0.7660 - val. loss: 0.4897 - val. acc.: 0.7620
# Epoch 98
# Epoch 98
# 36184/36184 [==============================] - 1s - loss: 0.4914 - acc.: 0.7651 - val. loss: 0.4903 - val. acc.: 0.7626
# 36184/36184 [==============================] - 1s - loss: 0.4914 - acc.: 0.7651 - val. loss: 0.4903 - val. acc.: 0.7626
# Epoch 99
# Epoch 99
# 36184/36184 [==============================] - 1s - loss: 0.4895 - acc.: 0.7643 - val. loss: 0.4912 - val. acc.: 0.7656
# 36184/36184 [==============================] - 1s - loss: 0.4895 - acc.: 0.7643 - val. loss: 0.4912 - val. acc.: 0.7656
# ('Test score:', 0.49124614456736354)
# ('Test accuracy:', 0.76558095834638273)

# %% [markdown]
# The best model used achieved 76.3% on the test set, making it the one with the highest performance on this dataset.

# %% [markdown]
# ## 3. Model selection

# %% [markdown]
# Now that we have tried multiple classifiers, let's compare them directly:

# %%
clfsDF = pd.DataFrame(clfs, 
                      columns=['Random classifier','LDA','Logistic regression','LinearSVM','rbfSVM',
                               'kNN','Naive Bayes','Decision tree','Random forest','Neural network'],
                      index=['train_acc','test_acc'])
clfsDF.head()
clfsDF.T.plot(kind='bar')

# %% [markdown]
# We see that the Neural Network is the best classifier for this task, followed by the rbf-SVM, but that the difference is relatively small between the best performing classifiers (logistic regression, kNN, RF, Linear SVM). This overall similar performance of the classifiers shows that this classification problem is really a feature extraction one: to get significant increases in accuracy, better features must be used. To this end, additional features such as the other 21 included in the original study might be useful; also, learning features directly from the data by using representation learning techniques might unveil new relevant features. Using more data, obviously, can also improve the results.
#
# Let's see if these tweaks can increase our best accuracy:

# %% [markdown]
# ### a. Dataset augmentation

# %% [markdown]
# As if often the case in EEG studies, ratios of band powers can be used to better inform us about ongoing mental activity. Let's compute additionnal features based on ratios with EEG_beta. First, we have to unnormalize the band power values to avoid division by very small values.

# %%
augFeats = feats.copy()

minFeatValue = feats.min().min()
feats2 = feats + minFeatValue*10

augFeats['EEG_alpha/beta'] = feats2.EEG_alpha/feats2.EEG_beta
augFeats['EEG_theta/beta'] = feats2.EEG_theta/feats2.EEG_beta
augFeats['EEG_gamma/beta'] = feats2.EEG_gamma/feats2.EEG_beta
augFeats['EEG_gamma/delta'] = feats2.EEG_gamma/feats2.EEG_delta

# Z-score normalization
augFeats = (augFeats - augFeats.mean(axis=0))/augFeats.std(axis=0)
augFeats['label'] = feats['label'].copy()

for featName in ['EEG_alpha/beta', 'EEG_theta/beta', 'EEG_gamma/beta', 'EEG_gamma/delta']:
    ax = plt.figure()
    augFeats.groupby('label')[featName].hist(alpha=0.4, bins=100)
    plt.xlabel(featName)
    plt.ylabel('Number of observations')
    plt.legend(['drowsy','awake'])

# %% [markdown]
# Now, let's train our best model again with all these features, on the whole training set:

# %%
# Separate data in train and test sets
X_train_aug, X_test_aug, y_train_aug, y_test_aug = cross_validation.train_test_split(                                    
                                                    augFeats.drop('label',axis=1), augFeats.label, 
                                                    test_size=0.15, random_state=rng)

# %%
X_train_NN = X_train_aug.astype('float32').values
X_test_NN = X_test_aug.astype('float32').values
print(X_train_aug.shape[0], 'train samples')
print(X_test_aug.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train_NN = np_utils.to_categorical(y_train_aug, nb_classes)
y_test_NN = np_utils.to_categorical(y_test_aug, nb_classes)

model.fit(X_train_NN, y_train_NN, batch_size=batch_size, nb_epoch=nb_epoch, show_accuracy=True, verbose=1,
         validation_data=(X_test_NN, y_test_NN))
test_score = model.evaluate(X_test_NN, y_test_NN, show_accuracy=True, verbose=0)
train_score = model.evaluate(X_train_NN, y_train_NN, show_accuracy=True, verbose=0)
print('Test score:', test_score[0])
print('Test accuracy:', test_score[1])
# Out:
# (36184, 'train samples')
# (6386, 'test samples')
# Train on 36184 samples, validate on 6386 samples
# Epoch 0
# Epoch 0
# Epoch 0
# Epoch 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-6c8bd79cdc7c> in <module>()
#       9
#      10 model.fit(X_train_NN, y_train_NN, batch_size=batch_size, nb_epoch=nb_epoch, show_accuracy=True, verbose=1,
# ---> 11          validation_data=(X_test_NN, y_test_NN))
#      12 test_score = model.evaluate(X_test_NN, y_test_NN, show_accuracy=True, verbose=0)
#      13 train_score = model.evaluate(X_train_NN, y_train_NN, show_accuracy=True, verbose=0)
#
# /usr/local/lib/python2.7/dist-packages/Keras-0.0.1-py2.7.egg/keras/models.pyc in fit(self, X, y, batch_size, nb_epoch, verbose, callbacks, validation_split, validation_data, shuffle, show_accuracy)
#     250                 ins = X_batch + [y_batch]
#     251                 if show_accuracy:
# --> 252                     loss, acc = self._train_with_acc(*ins)
#     253                     batch_logs['accuracy'] = acc
#     254                 else:
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     604                         self.fn.nodes[self.fn.position_of_error],
#     605                         self.fn.thunks[self.fn.position_of_error],
# --> 606                         storage_map=self.fn.storage_map)
#     607                 else:
#     608                     # For the c linker We don't have access from
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     593         t0_fn = time.time()
#     594         try:
# --> 595             outputs = self.fn()
#     596         except Exception:
#     597             if hasattr(self.fn, 'position_of_error'):
#
# ValueError: Shape mismatch: x has 11 cols (and 64 rows) but y has 7 rows (and 128 cols)
# Apply node that caused the error: Dot22(<TensorType(float64, matrix)>, <TensorType(float64, matrix)>)
# Inputs types: [TensorType(float64, matrix), TensorType(float64, matrix)]
# Inputs shapes: [(64, 11), (7, 128)]
# Inputs strides: [(88, 8), (1024, 8)]
# Inputs values: ['not shown', 'not shown']
#
# HINT: Re-running with most Theano optimization disabled could give you a back-trace of when this node was created. This can be done with by setting the Theano flag 'optimizer=fast_compile'. If that does not work, Theano optimizations can be disabled with 'optimizer=None'.
# HINT: Use the Theano flag 'exception_verbosity=high' for a debugprint and storage map footprint of this apply node.

# %% [markdown]
# Let's try with our second best model, the rbf-SVM:

# %%
rbfSVM_clfAug = bestKernelSVMclf
rbfSVM_clfAug.fit(X_train_aug, y_train_aug)

y_pred = rbfSVM_clfAug.predict(X_train_aug)
train_acc = accuracy_score(y_train_aug, y_pred)

y_pred = rbfSVM_clfAug.predict(X_test_aug)
test_acc = accuracy_score(y_test_aug, y_pred)
print(classification_report(y_test_aug, y_pred)) 
print('Validation accuracy: %0.3f'%train_acc)   
print('Test accuracy: %0.3f'%test_acc)   
print('')
# Out:
#              precision    recall  f1-score   support
#
#           0       0.72      0.75      0.73      2876
#           1       0.79      0.76      0.78      3510
#
# avg / total       0.76      0.76      0.76      6386
#
# Validation accuracy: 0.761
# Test accuracy: 0.756

# %% [markdown]
# This did not yield better results than using the original 7 features. Other transformations of the features (power, log, etc.) could be applied and might yield interesting results.

# %% [markdown]
# ### b. Other strategies to improve the results

# %% [markdown]
# The obvious way of improving the results would be to use a larger subset of or the complete preprocessed data available (25 subjects, 28 features).
#
# Similarly, this additionnal data could be used to perform unsupervised pre-training with stacked RBMs (like in the original paper) or with autoencoders trained on top of the pre-computed features. The currently unused classes (other stages of sleep) could thus be leveraged to improve the classification performance.
#
# Finally, new EEG/EOG/EMG features could be extracted in addition to the ones already computed. This could also be done as showcased in the original paper by *learning* features with a similar unsupervised pre-training approach, but carried on the raw data. Different deep neural networks architectures such as convolutional networks could also be used on the temporal data (such as on the spectrogram of each channel).

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Classification of two consciousness states ('drowsy' and 'awake') was attempted on a subset of the UCD sleep database. Seven features extracted on 42,570 one-second windows were classified using 7 different classifiers:
# 1. LDA
# 2. Logistic regression
# 3. Linear SVM
# 4. Kernel SVM
# 5. k-NN
# 6. Naive Bayes
# 7. Decision tree
# 8. Random forest
#
# The best performing classifier was the rbf-SVM with 75.6% accuracy on the test set. However, differences between classifiers were not huge. A nested cross-validation would allow to make sure this was the optimal classifier by giving a better estimate of the test accuracy (instead of a point estimate).
#
# Using more/better features, such as hand-engineered or learned-from-data features, is probably the best way of increasing the accuracy of the proposed models.
